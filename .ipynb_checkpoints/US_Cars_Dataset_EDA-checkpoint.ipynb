# %% [markdown]
# # Exploratory Data Analysis of US Car Sales

# %% [markdown]
# Introductory Exploratory Data Analysis of US Car Auction Data. <br>
# Serves as a Tutorial for a Future EDA Projects. <br>
# Source: https://www.kaggle.com/datasets/doaaalsenani/usa-cers-dataset

# %% [markdown]
# ## Import Data and libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('USA_cars_datasets.csv')

# %% [markdown]
# ## Explore Data
# - Shape of Data
# - Data types of each Column
# - Unique values per Column

# %%
df.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df.shape
# Out:
# (2499, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2499 non-null   int64
#  1   price         2499 non-null   int64
#  2   brand         2499 non-null   object
#  3   model         2499 non-null   object
#  4   year          2499 non-null   int64
#  5   title_status  2499 non-null   object
#  6   mileage       2499 non-null   float64
#  7   color         2499 non-null   object
#  8   vin           2499 non-null   object
#  9   lot           2499 non-null   int64
#  10  state         2499 non-null   object
#  11  country       2499 non-null   object
#  12  condition     2499 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 253.9+ KB

# %%
df['year'].dtype
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'price', 'brand', 'model', 'year', 'title_status',
#        'mileage', 'color', 'vin', 'lot', 'state', 'country', 'condition'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0         price         year       mileage           lot
# count  2499.000000   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   1249.000000  18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std     721.543484  12116.094936     3.442656  5.970552e+04  2.038772e+05
# min       0.000000      0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%     624.500000  10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    1249.000000  16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    1873.500000  25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    2498.000000  84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %%
df.nunique()
# Out:
# Unnamed: 0      2499
# price            790
# brand             28
# model            127
# year              30
# title_status       2
# mileage         2439
# color             49
# vin             2495
# lot             2495
# state             44
# country            2
# condition         47
# dtype: int64

# %%
df['title_status'].unique()
# Out:
# array(['clean vehicle', 'salvage insurance'], dtype=object)

# %% [markdown]
# ## Cleaning and adjusting data
# - Get rows containig null values
# - Get rows containig duplicated values
# - Adjust Data types if needed
# - Rename Columns if needed
# - Drop unnecasaary Columns
# - Create new rows based on exsiting Data

# %% [markdown]
# Get null rows  and remove them

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
df.fillna(df.median())
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
df = df.dropna(how='all')

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, price, brand, model, year, title_status, mileage, color, vin, lot, state, country, condition]
# Index: []

# %% [markdown]
# Get duplicated rows

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, price, brand, model, year, title_status, mileage, color, vin, lot, state, country, condition]
# Index: []

# %% [markdown]
# Change Datatypes

# %%
df['color'] = df['color'].astype('O')
df['year'] = pd.to_numeric(df['year'])

# %% [markdown]
# Drop unnecesarry Data

# %%
df = df.drop(['Unnamed: 0','vin','lot', 'condition'],axis=1).copy()
df.head()
# Out:
#    price      brand    model  year   title_status   mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1   2899       ford       se  2011  clean vehicle  190552.0  silver
# 2   5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3  25000       ford     door  2014  clean vehicle   64146.0    blue
# 4  27700  chevrolet     1500  2018  clean vehicle    6654.0     red
#
#         state country
# 0  new jersey     usa
# 1   tennessee     usa
# 2     georgia     usa
# 3    virginia     usa
# 4     florida     usa

# %% [markdown]
# Rename columns, keep consistent format

# %%
df.rename(columns={'title_status': 'condition'})
# Out:
#       price      brand    model  year      condition   mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1      2899       ford       se  2011  clean vehicle  190552.0  silver
# 2      5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3     25000       ford     door  2014  clean vehicle   64146.0    blue
# 4     27700  chevrolet     1500  2018  clean vehicle    6654.0     red
# ...     ...        ...      ...   ...            ...       ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle   23609.0     red
# 2495   9200     nissan    versa  2018  clean vehicle   34553.0  silver
# 2496   9200     nissan    versa  2018  clean vehicle   31594.0  silver
# 2497   9200     nissan    versa  2018  clean vehicle   32557.0   black
# 2498   9200     nissan    versa  2018  clean vehicle   31371.0  silver
#
#            state country
# 0     new jersey     usa
# 1      tennessee     usa
# 2        georgia     usa
# ...

# %% [markdown]
# Creating new column

# %%
df['age'] = pd.Timestamp.now().year - df['year']

# %% [markdown]
# Creating new DF where Car Brands containt either top 3 Brand's and mark rest as Other

# %%
df['brand'].value_counts().iloc[:3]
# Out:
# ford      1235
# dodge      432
# nissan     312
# Name: brand, dtype: int64

# %%
top_brands_selection = df.copy()

def reassign(x):
    if x in ['ford', 'nissan', 'dodge']:
        return x
    else:
        return 'other'
    
top_brands_selection['brand'] = top_brands_selection['brand'].apply(lambda x: reassign(x))
# Out:
#       price   brand    model  year   title_status   mileage   color  \
# 0      6300   other  cruiser  2008  clean vehicle  274117.0   black
# 1      2899    ford       se  2011  clean vehicle  190552.0  silver
# 2      5350   dodge      mpv  2018  clean vehicle   39590.0  silver
# 3     25000    ford     door  2014  clean vehicle   64146.0    blue
# 4     27700   other     1500  2018  clean vehicle    6654.0     red
# ...     ...     ...      ...   ...            ...       ...     ...
# 2494   7800  nissan    versa  2019  clean vehicle   23609.0     red
# 2495   9200  nissan    versa  2018  clean vehicle   34553.0  silver
# 2496   9200  nissan    versa  2018  clean vehicle   31594.0  silver
# 2497   9200  nissan    versa  2018  clean vehicle   32557.0   black
# 2498   9200  nissan    versa  2018  clean vehicle   31371.0  silver
#
#            state country  age
# 0     new jersey     usa   15
# 1      tennessee     usa   12
# 2        georgia     usa    5
# ...

# %% [markdown]
# ## Univariet Analysis
# - Focuses on analyzing each feature in the dataset independently
# - Identifying potential issues: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values
# - Descriptive Statistics
#     - Mean
#     - Variance
#     - Standard Deviation
#     - Range
#     - Quantils
#     - Interquartile range (IQR)
#     - Skewness
# - Visualsation (Boxplot,Histogram,KDE)
# - Identifying Outliers

# %% [markdown]
# #### PRICE

# %%
price_histogram = sns.histplot(df['price'], kde=True, bins=50)

# %%
df['price'].skew()
# Out:
# 0.9227307836499805

# %%
df['price'].plot(kind='box')
df.describe()['price']
# Out:
# count     2499.000000
# mean     18767.671469
# std      12116.094936
# min          0.000000
# 25%      10200.000000
# 50%      16900.000000
# 75%      25555.500000
# max      84900.000000
# Name: price, dtype: float64

# %% [markdown]
# IQR

# %%
df['price'].quantile(0.75) - df['price'].quantile(0.25)
# Out:
# 15355.5

# %% [markdown]
# Identifying outliers

# %%
df['price'].quantile(0.95)
# Out:
# 42029.99999999997

# %% [markdown]
# Trimming top outliers

# %%
price_trimmed_top5_percent = df[df['price'] < df['price'].quantile(0.95)].copy()

price_trimmed_top5_percent.describe()
price_trimmed_top5_percent['price'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=price_trimmed_top5_percent,x='price',bins=50,kde=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# <b>CONCLUSION</b>

# %% [markdown]
# - Price is Log Normally Distributed
# - We Detect a large amount of outlieres

# %% [markdown]
# #### CAR AGE

# %%
car_distribition =sns.histplot(df[df['age']<20]['age'], kde=True)

# %%
df['age'].skew()
# Out:
# 3.559397739875532

# %%
df['age'].plot(kind='box')
df['age'].describe()
# Out:
# count    2499.000000
# mean        6.285714
# std         3.442656
# min         3.000000
# 25%         4.000000
# 50%         5.000000
# 75%         7.000000
# max        50.000000
# Name: age, dtype: float64

# %%
df['age'].quantile(0.90)
# Out:
# 10.0

# %% [markdown]
# <b>CONCLUSION</b>

# %% [markdown]
# - Very supressed, lotof extreme values.90% Of values beeing under 10 Years.
# - Distribution of cars less then 20 years old. <br>
# Higly skewed to the left, with slow decrese.
# - 90% of Cars from the Dataset are younger then 10 years

# %% [markdown]
# #### MILEAGE

# %%
price_histogram = sns.histplot(df['mileage'], kde=True, bins=50)

# %%
df['mileage'].plot(kind='box')
df['mileage'].describe()
# Out:
# count    2.499000e+03
# mean     5.229869e+04
# std      5.970552e+04
# min      0.000000e+00
# 25%      2.146650e+04
# 50%      3.536500e+04
# 75%      6.347250e+04
# max      1.017936e+06
# Name: mileage, dtype: float64

# %%
df['mileage'].quantile(0.90)
# Out:
# 111615.20000000001

# %% [markdown]
# <b>CONCLUSION</b>
# - Log Normal distributed
# - Extreme outlieres
# - Mileage Distribution by brand is fairly similar

# %% [markdown]
# <b>BRAND</b>

# %%
df['brand'].value_counts()
df['brand'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='brand'>

# %%
df['brand'].value_counts().iloc[:3]
# Out:
# ford      1235
# dodge      432
# nissan     312
# Name: brand, dtype: int64

# %%
df['brand'].value_counts(normalize=True).iloc[:3]*100
# Out:
# ford      49.419768
# dodge     17.286915
# nissan    12.484994
# Name: brand, dtype: float64

# %%
(df.query('brand in ["ford","dodge","nissan"]')['brand'].value_counts().sum()/df['brand'].value_counts().sum())*100
# Out:
# 79.19167667066827

# %% [markdown]
# <b>CONCLUSION</b>
# - Top 3 Brands account for 79% of all Cars in the Data

# %% [markdown]
# <b>STATE</b>

# %%
df['state'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['state'].value_counts(normalize=True).iloc[:10]*100
# Out:
# pennsylvania      11.964786
# florida            9.843938
# texas              8.563425
# california         7.603041
# michigan           6.762705
# north carolina     5.842337
# minnesota          4.761905
# illinois           4.521809
# wisconsin          3.761505
# virginia           3.601441
# Name: state, dtype: float64

# %% [markdown]
# <b>CONCLUSION</b>

# %% [markdown]
# ## Bivariate Analysis
# - Determining the correlation between two features
# - Correlation
# - Linear regresion
# - Visualisation (Heatmap, Scatterplot)
#
# Type of Relationship
# 1. <b>Numerical - Numerical</b><br>
# You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots b. Check correlation coecent to check linear relationship
# 2. <b>Numerical - Categorical</b><br>
# Create visualizations that compare the distribution of the numerical data across different categories of the categorical data.
# a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots
# 3. <b>Categorical - Categorical</b><br>
# You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column. b. You can plots like heatmap, stacked barplots, treemaps

# %% [markdown]
# <b>Exploring Relationship between Age and Price</b>

# %% [markdown]
# Removing Outlieres

# %%
temp = df[(df['age'] < 30) & (df['price'] < 80000)]

# %%
sns.scatterplot(data=temp,x='age', y='price')
# Out:
# <AxesSubplot:xlabel='age', ylabel='price'>

# %%
temp[['price','age']].corr()
# Out:
#          price      age
# price  1.00000 -0.44292
# age   -0.44292  1.00000

# %% [markdown]
# <b>Exploring Relationship between Age and Mileage</b>

# %%
sns.scatterplot(x=df['age'], y=df['mileage'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='mileage'>

# %%
sns.pairplot(df, hue='brand')

# %% [markdown]
# ### Multivariate Analysis
# - Consists of understanding the relationship between two or more variables.

# %% [markdown]
# #### Exploring the relationship between PRICE,MILEAGE and AGE of car

# %% [markdown]
# Comparing PRICE distribution of top 3 Car makers in the Dataset

# %%
price_histogram = sns.histplot(data=top_brands_selection, x='price', kde=True, stat='percent', hue='brand',common_norm=False)

# %%
subset_corr = df[['price','mileage','age']]
correlation = subset_corr.corr()
correlation
# Out:
#             price   mileage       age
# price    1.000000 -0.400838 -0.418274
# mileage -0.400838  1.000000  0.594686
# age     -0.418274  0.594686  1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=top_brands_selection, x='mileage', y=df['price'], hue='brand')
df[['price','mileage']].corr()

for i in ['ford','nissan','dodge']:
    brand_corr= df[df['brand']== i]
    print(i,brand_corr[['price','mileage']].corr())
# Out:
# ford             price   mileage
# price    1.000000 -0.451986
# mileage -0.451986  1.000000
# nissan             price   mileage
# price    1.000000 -0.487085
# mileage -0.487085  1.000000
# dodge             price   mileage
# price    1.000000 -0.612535
# mileage -0.612535  1.000000

# %% [markdown]
# <b>CONCLUSION</b><br>
# Medium negative correlation between MILEAGE and PRICE: expected, correlation is not higher because other factors such as BRAND,AGE<br>
# Medium negative correlation between AGE and PRICE: expected, correlation is not higher because other factors such as BRAND,MILEAGE <br>
# Medium positive correlaation between MILEAGE and AGE: expected higher |

# %% [markdown]
# ### Linear regression - relationship between mileage and price
